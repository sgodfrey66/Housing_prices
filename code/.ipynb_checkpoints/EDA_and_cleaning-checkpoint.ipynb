# %% [markdown]
# # Project 2 Ames Housing

# %% [markdown]
# ## Imports

# %%
# Imports:
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline


# Set the graph style
sns.set_style('whitegrid')

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read in data

# %%
# Set relative data path
data_path = "../datasets"
test_file_name = "test.csv"
train_file_name = "train.csv"

a_tst = pd.read_csv(os.path.join(data_path, test_file_name))
a_trn = pd.read_csv(os.path.join(data_path, train_file_name))

# %% [markdown]
# ### View dataframes and data
#
# 1. Look at all columns for both the train and test data sets
# 2. Pick a set of features to examine first
# 3. Explore these features individually

# %%
# Look at the train and test data sets
print("Train", a_trn.shape)
print(a_trn.columns)
# print(a_trn.info())

print ("Test", a_tst.shape)
print(a_tst.columns)
# print(a_tst.info())
# Out:
# Train (2051, 81)
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'SalePrice'],
#       dtype='object')
# Test (879, 80)
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type'],
#       dtype='object')

# %% [markdown]
# ### variable notes
#
# * Excluded from analysis
#     * Low Qual Fin SF has only 33 values that are not zero
#     * 1st Flr SF + 2nd Flr SF = Gr Liv Area except for 33 values used Gr Liv Area
#     * Lot Frontage has 330 missing values
#
#
# * Missing values (NaN values)
#     * Set Bsmt Full Bath NaN values to 0 (2 values)
#     * Set Bsmt Half Bath NaN values to 0 (2 values)
#     * Set Total Bsmt SF NaN values to 0 (1 values)
#     * Set Bsmt Cond NaN values to NA (55 values in train dataset)
#     * Set Garage Type NaN values to NA (113 values in train dataset)
#     * Set Pool QC values to NA (2042 values in train dataset)
#     * Set Misc Features values to NA (1986 values in train dataset)

# %%
# Examine Low Qual Fin SF
a_trn[a_trn['Low Qual Fin SF']!=0].shape
# Out:
# (33, 81)

# %%
# Examine '1st Flr SF' and '2nd Flr SF' and 'GR Liv Area'
a_trn[(a_trn['Gr Liv Area'] - (a_trn['1st Flr SF'] + a_trn['2nd Flr SF']))!=0][['Gr Liv Area','1st Flr SF','2nd Flr SF']]
# Out:
#       Gr Liv Area  1st Flr SF  2nd Flr SF
# 249           845         640           0
# 269          1200         520         600
# 320          1382         854           0
# 356          1526        1013           0
# 382          2229         929         929
# 497          1639        1166           0
# 705          1594         828         658
# 828          2377        1313           0
# 858          3395        1440        1440
# 918          1869        1188         561
# 951          2358         938        1215
# 1026         2168         928         928
# 1035         3608        1518        1518
# 1040         1223         520         623
# 1051          754         520           0
# 1234         1316         926           0
# 1239         1969        1272           0
# 1301         1484         866         504
# 1333         1728        1216           0
# 1417         1656         808         704
# 1419         1522        1008           0
# 1433         3082        1687         998
# 1468         1200         520         600
# 1515         1700         880         680
# 1563         3086        1636         971
# 1599         1774         904         611
# 1640         1480        1044           0
# 1661          935         779           0
# 1688         2555        1423         748
# 1756         1176         816           0
# 1933         2320        1547         720
# 1961         1531        1169           0
# 2042         1414         964           0

# %%
# Examine Lot Frontage
feat_check = ['Lot Frontage','Utilities','Lot Config',
       'House Style','Year Remod/Add','Exter Qual','Exter Cond','Bsmt Cond',
       'BsmtFin Type 1','Heating QC', 'Central Air','Functional',
       'Enclosed Porch','Garage Type','Pool QC','Misc Feature', 'Mo Sold']
a = a_trn[feat_check].isnull().sum()
b = a_tst[feat_check].isnull().sum()

# %%
print("Null values Train: Test")
for i in range(len(a)):
    print("%s: %d, %d" % (a.index[i], a[i], b[i]))
# Out:
# Null values Train: Test
# Lot Frontage: 330, 160
# Utilities: 0, 0
# Lot Config: 0, 0
# House Style: 0, 0
# Year Remod/Add: 0, 0
# Exter Qual: 0, 0
# Exter Cond: 0, 0
# Bsmt Cond: 55, 25
# BsmtFin Type 1: 55, 25
# Heating QC: 0, 0
# Central Air: 0, 0
# Functional: 0, 0
# Enclosed Porch: 0, 0
# Garage Type: 113, 44
# Pool QC: 2042, 875
# Misc Feature: 1986, 838
# Mo Sold: 0, 0

# %%
# Create a subset list of features
targ = ['SalePrice']
feat_1 = ['MS SubClass', 'MS Zoning', 'Lot Area', 'Utilities', 'Lot Config', 'Neighborhood', 'Bldg Type',
         'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add','Exter Qual',
         'Exter Cond', 'Bsmt Cond', 'Total Bsmt SF','Heating QC', 'Central Air',
         'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath',
         'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen Qual', 'Functional','Enclosed Porch',
         'Garage Type', 'Pool QC','Misc Feature','Mo Sold', 'Yr Sold', 'Sale Type']

X1_trn = a_trn[feat_1]
X1_tst = a_tst[feat_1]

# %%
# Examine the X1_trn and X1_tst
for col in X1_trn.columns:
    print("Train: %15s %5d %15s" % (col, X1_trn[col].isnull().sum(), X1_trn[col].dtypes))
    print(" Test: %15s %5d %15s" % (col, X1_tst[col].isnull().sum(), X1_tst[col].dtypes))
   

# print(X1_trn.info())
# print(X1_tst.info())
# Out:
# Train:     MS SubClass     0           int64
#  Test:     MS SubClass     0           int64
# Train:       MS Zoning     0          object
#  Test:       MS Zoning     0          object
# Train:        Lot Area     0           int64
#  Test:        Lot Area     0           int64
# Train:       Utilities     0          object
#  Test:       Utilities     0          object
# Train:      Lot Config     0          object
#  Test:      Lot Config     0          object
# Train:    Neighborhood     0          object
#  Test:    Neighborhood     0          object
# Train:       Bldg Type     0          object
#  Test:       Bldg Type     0          object
# Train:     House Style     0          object
#  Test:     House Style     0          object
# Train:    Overall Qual     0           int64
#  Test:    Overall Qual     0           int64
# Train:    Overall Cond     0           int64
#  Test:    Overall Cond     0           int64
# Train:      Year Built     0           int64
#  Test:      Year Built     0           int64
# Train:  Year Remod/Add     0           int64
#  Test:  Year Remod/Add     0           int64
# Train:      Exter Qual     0          object
#  Test:      Exter Qual     0          object
# Train:      Exter Cond     0          object
#  Test:      Exter Cond     0          object
# Train:       Bsmt Cond    55          object
#  Test:       Bsmt Cond    25          object
# Train:   Total Bsmt SF     1         float64
#  Test:   Total Bsmt SF     0           int64
# Train:      Heating QC     0          object
#  Test:      Heating QC     0          object
# Train:     Central Air     0          object
#  Test:     Central Air     0          object
# Train:     Gr Liv Area     0           int64
#  Test:     Gr Liv Area     0           int64
# Train:  Bsmt Full Bath     2         float64
#  Test:  Bsmt Full Bath     0           int64
# Train:  Bsmt Half Bath     2         float64
#  Test:  Bsmt Half Bath     0           int64
# Train:       Full Bath     0           int64
#  Test:       Full Bath     0           int64
# Train:       Half Bath     0           int64
#  Test:       Half Bath     0           int64
# Train:   Bedroom AbvGr     0           int64
#  Test:   Bedroom AbvGr     0           int64
# Train:    Kitchen Qual     0          object
#  Test:    Kitchen Qual     0          object
# Train:      Functional     0          object
#  Test:      Functional     0          object
# Train:  Enclosed Porch     0           int64
#  Test:  Enclosed Porch     0           int64
# Train:     Garage Type   113          object
#  Test:     Garage Type    44          object
# Train:         Pool QC  2042          object
#  Test:         Pool QC   875          object
# Train:    Misc Feature  1986          object
#  Test:    Misc Feature   838          object
# Train:         Mo Sold     0           int64
#  Test:         Mo Sold     0           int64
# Train:         Yr Sold     0           int64
#  Test:         Yr Sold     0           int64
# Train:       Sale Type     0          object
#  Test:       Sale Type     0          object

# %% [markdown]
# ### Handle NaN values

# %%
# Find the null values
col = 'Bsmt Full Bath'
df = X1_trn
df[df[col].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Area Utilities Lot Config Neighborhood  \
# 616            20        RL     47007    AllPub     Inside      Edwards
# 1327           20        RM      5940    AllPub        FR3      BrkSide
#
#      Bldg Type House Style  Overall Qual  Overall Cond  ...  Bedroom AbvGr  \
# 616       1Fam      1Story             5             7  ...              5
# 1327      1Fam      1Story             4             7  ...              2
#
#       Kitchen Qual Functional Enclosed Porch Garage Type  Pool QC  \
# 616             Ex        Typ              0      Attchd      NaN
# 1327            TA        Typ              0      Detchd      NaN
#
#      Misc Feature Mo Sold  Yr Sold  Sale Type
# 616           NaN       7     2008        WD
# 1327          NaN       4     2008      ConLD
#
# [2 rows x 33 columns]

# %%
# Find the null values
col = 'Bsmt Half Bath'
df[df[col].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Area Utilities Lot Config Neighborhood  \
# 616            20        RL     47007    AllPub     Inside      Edwards
# 1327           20        RM      5940    AllPub        FR3      BrkSide
#
#      Bldg Type House Style  Overall Qual  Overall Cond  ...  Bedroom AbvGr  \
# 616       1Fam      1Story             5             7  ...              5
# 1327      1Fam      1Story             4             7  ...              2
#
#       Kitchen Qual Functional Enclosed Porch Garage Type  Pool QC  \
# 616             Ex        Typ              0      Attchd      NaN
# 1327            TA        Typ              0      Detchd      NaN
#
#      Misc Feature Mo Sold  Yr Sold  Sale Type
# 616           NaN       7     2008        WD
# 1327          NaN       4     2008      ConLD
#
# [2 rows x 33 columns]

# %%
# Find the null values
col = 'Total Bsmt SF'
df[df[col].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Area Utilities Lot Config Neighborhood  \
# 1327           20        RM      5940    AllPub        FR3      BrkSide
#
#      Bldg Type House Style  Overall Qual  Overall Cond  ...  Bedroom AbvGr  \
# 1327      1Fam      1Story             4             7  ...              2
#
#       Kitchen Qual Functional Enclosed Porch Garage Type  Pool QC  \
# 1327            TA        Typ              0      Detchd      NaN
#
#      Misc Feature Mo Sold  Yr Sold  Sale Type
# 1327          NaN       4     2008      ConLD
#
# [1 rows x 33 columns]

# %%
# Find and replace null values with 0
df_l = [X1_trn, X1_tst]
col_l = ['Bsmt Full Bath','Bsmt Half Bath','Total Bsmt SF']

for df in df_l:
    for col in col_l:
        # Fill the null values with NA
        df[col] = df[col].fillna(0)

# %%
# Find and replace null values with NA
df_l = [X1_trn, X1_tst]
col_l = ['Bsmt Cond','Garage Type', 'Pool QC','Misc Feature']

for df in df_l:
    for col in col_l:
        # Fill the null values with NA
        df[col] = df[col].fillna("NA")

# %%
# Examine the X1_trn and X1_tst
for col in X1_trn.columns:
    print("Train: %15s %5d %15s" % (col, X1_trn[col].isnull().sum(), X1_trn[col].dtypes))
    print(" Test: %15s %5d %15s" % (col, X1_tst[col].isnull().sum(), X1_tst[col].dtypes))
# Out:
# Train:     MS SubClass     0           int64
#  Test:     MS SubClass     0           int64
# Train:       MS Zoning     0          object
#  Test:       MS Zoning     0          object
# Train:        Lot Area     0           int64
#  Test:        Lot Area     0           int64
# Train:       Utilities     0          object
#  Test:       Utilities     0          object
# Train:      Lot Config     0          object
#  Test:      Lot Config     0          object
# Train:    Neighborhood     0          object
#  Test:    Neighborhood     0          object
# Train:       Bldg Type     0          object
#  Test:       Bldg Type     0          object
# Train:     House Style     0          object
#  Test:     House Style     0          object
# Train:    Overall Qual     0           int64
#  Test:    Overall Qual     0           int64
# Train:    Overall Cond     0           int64
#  Test:    Overall Cond     0           int64
# Train:      Year Built     0           int64
#  Test:      Year Built     0           int64
# Train:  Year Remod/Add     0           int64
#  Test:  Year Remod/Add     0           int64
# Train:      Exter Qual     0          object
#  Test:      Exter Qual     0          object
# Train:      Exter Cond     0          object
#  Test:      Exter Cond     0          object
# Train:       Bsmt Cond     0          object
#  Test:       Bsmt Cond     0          object
# Train:   Total Bsmt SF     0         float64
#  Test:   Total Bsmt SF     0           int64
# Train:      Heating QC     0          object
#  Test:      Heating QC     0          object
# Train:     Central Air     0          object
#  Test:     Central Air     0          object
# Train:     Gr Liv Area     0           int64
#  Test:     Gr Liv Area     0           int64
# Train:  Bsmt Full Bath     0         float64
#  Test:  Bsmt Full Bath     0           int64
# Train:  Bsmt Half Bath     0         float64
#  Test:  Bsmt Half Bath     0           int64
# Train:       Full Bath     0           int64
#  Test:       Full Bath     0           int64
# Train:       Half Bath     0           int64
#  Test:       Half Bath     0           int64
# Train:   Bedroom AbvGr     0           int64
#  Test:   Bedroom AbvGr     0           int64
# Train:    Kitchen Qual     0          object
#  Test:    Kitchen Qual     0          object
# Train:      Functional     0          object
#  Test:      Functional     0          object
# Train:  Enclosed Porch     0           int64
#  Test:  Enclosed Porch     0           int64
# Train:     Garage Type     0          object
#  Test:     Garage Type     0          object
# Train:         Pool QC     0          object
#  Test:         Pool QC     0          object
# Train:    Misc Feature     0          object
#  Test:    Misc Feature     0          object
# Train:         Mo Sold     0           int64
#  Test:         Mo Sold     0           int64
# Train:         Yr Sold     0           int64
#  Test:         Yr Sold     0           int64
# Train:       Sale Type     0          object
#  Test:       Sale Type     0          object

# %% [markdown]
# ### Show maximum and minimum values

# %%
# Describe
X1_trn.describe().T
# Out:
#                  count          mean          std     min     25%     50%  \
# MS SubClass     2051.0     57.008776    42.824223    20.0    20.0    50.0
# Lot Area        2051.0  10065.208191  6742.488909  1300.0  7500.0  9430.0
# Overall Qual    2051.0      6.112140     1.426271     1.0     5.0     6.0
# Overall Cond    2051.0      5.562165     1.104497     1.0     5.0     5.0
# Year Built      2051.0   1971.708922    30.177889  1872.0  1953.5  1974.0
# Year Remod/Add  2051.0   1984.190151    21.036250  1950.0  1964.5  1993.0
# Total Bsmt SF   2051.0   1057.471965   449.908003     0.0   793.0   994.0
# Gr Liv Area     2051.0   1499.330083   500.447829   334.0  1129.0  1444.0
# Bsmt Full Bath  2051.0      0.427109     0.522589     0.0     0.0     0.0
# Bsmt Half Bath  2051.0      0.063384     0.251590     0.0     0.0     0.0
# Full Bath       2051.0      1.577279     0.549279     0.0     1.0     2.0
# Half Bath       2051.0      0.371039     0.501043     0.0     0.0     0.0
# Bedroom AbvGr   2051.0      2.843491     0.826618     0.0     2.0     3.0
# Enclosed Porch  2051.0     22.571916    59.845110     0.0     0.0     0.0
# Mo Sold         2051.0      6.219893     2.744736     1.0     4.0     6.0
# Yr Sold         2051.0   2007.775719     1.312014  2006.0  2007.0  2008.0
#
#                     75%       max
# MS SubClass        70.0     190.0
# Lot Area        11513.5  159000.0
# Overall Qual        7.0      10.0
# Overall Cond        6.0       9.0
# Year Built       2001.0    2010.0
# Year Remod/Add   2004.0    2010.0
# Total Bsmt SF    1318.5    6110.0
# Gr Liv Area      1728.5    5642.0
# Bsmt Full Bath      1.0       3.0
# Bsmt Half Bath      0.0       2.0
# Full Bath           2.0       4.0
# Half Bath           1.0       2.0
# Bedroom AbvGr       3.0       8.0
# Enclosed Porch      0.0     432.0
# Mo Sold             8.0      12.0
# Yr Sold          2009.0    2010.0

# %%
# Describe
X1_tst.describe().T
# Out:
#                 count          mean           std     min     25%     50%  \
# MS SubClass     879.0     58.270762     42.211389    20.0    20.0    50.0
# Lot Area        879.0  10340.920364  10047.335167  1477.0  7298.5  9453.0
# Overall Qual    879.0      6.054608      1.374756     2.0     5.0     6.0
# Overall Cond    879.0      5.565415      1.128422     1.0     5.0     5.0
# Year Built      879.0   1970.533561     30.403527  1880.0  1954.0  1972.0
# Year Remod/Add  879.0   1984.444824     20.454546  1950.0  1967.0  1992.0
# Total Bsmt SF   879.0   1036.750853    419.258428     0.0   790.0   975.0
# Gr Liv Area     879.0   1500.531286    517.413260   407.0  1114.0  1436.0
# Bsmt Full Bath  879.0      0.440273      0.529983     0.0     0.0     0.0
# Bsmt Half Bath  879.0      0.055745      0.229560     0.0     0.0     0.0
# Full Bath       879.0      1.541524      0.560908     0.0     1.0     2.0
# Half Bath       879.0      0.399317      0.506045     0.0     0.0     0.0
# Bedroom AbvGr   879.0      2.879408      0.830249     0.0     2.0     3.0
# Enclosed Porch  879.0     24.037543     73.212237     0.0     0.0     0.0
# Mo Sold         879.0      6.207053      2.644097     1.0     5.0     6.0
# Yr Sold         879.0   2007.824801      1.327396  2006.0  2007.0  2008.0
#
#                     75%       max
# MS SubClass        70.0     190.0
# Lot Area        11606.5  215245.0
# Overall Qual        7.0      10.0
# Overall Cond        6.0       9.0
# Year Built       2000.0    2010.0
# Year Remod/Add   2003.0    2010.0
# Total Bsmt SF    1248.0    3138.0
# Gr Liv Area      1781.0    4676.0
# Bsmt Full Bath      1.0       2.0
# Bsmt Half Bath      0.0       1.0
# Full Bath           2.0       4.0
# Half Bath           1.0       2.0
# Bedroom AbvGr       3.0       6.0
# Enclosed Porch      0.0    1012.0
# Mo Sold             8.0      12.0
# Yr Sold          2009.0    2010.0

# %%
# Look at the maximum and minimum values
df = X1_trn
# check for min and max values
for column in df.columns:
    print("Column: %15s  min: %10s  max: %10s" % (column, str(df[column].min()), str(df[column].max())))
# Out:
# Column:     MS SubClass  min:         20  max:        190
# Column:       MS Zoning  min:    A (agr)  max:         RM
# Column:        Lot Area  min:       1300  max:     159000
# Column:       Utilities  min:     AllPub  max:     NoSewr
# Column:      Lot Config  min:     Corner  max:     Inside
# Column:    Neighborhood  min:    Blmngtn  max:    Veenker
# Column:       Bldg Type  min:       1Fam  max:     TwnhsE
# Column:     House Style  min:     1.5Fin  max:       SLvl
# Column:    Overall Qual  min:          1  max:         10
# Column:    Overall Cond  min:          1  max:          9
# Column:      Year Built  min:       1872  max:       2010
# Column:  Year Remod/Add  min:       1950  max:       2010
# Column:      Exter Qual  min:         Ex  max:         TA
# Column:      Exter Cond  min:         Ex  max:         TA
# Column:       Bsmt Cond  min:         Ex  max:         TA
# Column:   Total Bsmt SF  min:        0.0  max:     6110.0
# Column:      Heating QC  min:         Ex  max:         TA
# Column:     Central Air  min:          N  max:          Y
# Column:     Gr Liv Area  min:        334  max:       5642
# Column:  Bsmt Full Bath  min:        0.0  max:        3.0
# Column:  Bsmt Half Bath  min:        0.0  max:        2.0
# Column:       Full Bath  min:          0  max:          4
# Column:       Half Bath  min:          0  max:          2
# Column:   Bedroom AbvGr  min:          0  max:          8
# Column:    Kitchen Qual  min:         Ex  max:         TA
# Column:      Functional  min:       Maj1  max:        Typ
# Column:  Enclosed Porch  min:          0  max:        432
# Column:     Garage Type  min:     2Types  max:         NA
# Column:         Pool QC  min:         Ex  max:         TA
# Column:    Misc Feature  min:       Elev  max:       TenC
# Column:         Mo Sold  min:          1  max:         12
# Column:         Yr Sold  min:       2006  max:       2010
# Column:       Sale Type  min:        COD  max:        WD

# %%
# Look at the maximum and minimum values
df = X1_tst
# check for min and max values
for column in df.columns:
    print("Column: %15s  min: %10s  max: %10s" % (column, str(df[column].min()), str(df[column].max())))
# Out:
# Column:     MS SubClass  min:         20  max:        190
# Column:       MS Zoning  min:    C (all)  max:         RM
# Column:        Lot Area  min:       1477  max:     215245
# Column:       Utilities  min:     AllPub  max:     NoSewr
# Column:      Lot Config  min:     Corner  max:     Inside
# Column:    Neighborhood  min:    Blmngtn  max:    Veenker
# Column:       Bldg Type  min:       1Fam  max:     TwnhsE
# Column:     House Style  min:     1.5Fin  max:       SLvl
# Column:    Overall Qual  min:          2  max:         10
# Column:    Overall Cond  min:          1  max:          9
# Column:      Year Built  min:       1880  max:       2010
# Column:  Year Remod/Add  min:       1950  max:       2010
# Column:      Exter Qual  min:         Ex  max:         TA
# Column:      Exter Cond  min:         Ex  max:         TA
# Column:       Bsmt Cond  min:         Fa  max:         TA
# Column:   Total Bsmt SF  min:          0  max:       3138
# Column:      Heating QC  min:         Ex  max:         TA
# Column:     Central Air  min:          N  max:          Y
# Column:     Gr Liv Area  min:        407  max:       4676
# Column:  Bsmt Full Bath  min:          0  max:          2
# Column:  Bsmt Half Bath  min:          0  max:          1
# Column:       Full Bath  min:          0  max:          4
# Column:       Half Bath  min:          0  max:          2
# Column:   Bedroom AbvGr  min:          0  max:          6
# Column:    Kitchen Qual  min:         Ex  max:         TA
# Column:      Functional  min:       Maj1  max:        Typ
# Column:  Enclosed Porch  min:          0  max:       1012
# Column:     Garage Type  min:     2Types  max:         NA
# Column:         Pool QC  min:         Ex  max:         TA
# Column:    Misc Feature  min:       Gar2  max:       Shed
# Column:         Mo Sold  min:          1  max:         12
# Column:         Yr Sold  min:       2006  max:       2010
# Column:       Sale Type  min:        COD  max:        WD

# %%
# Show value counts
df = X1_trn
col = 'MS SubClass'
print(df[col].value_counts())

df = X1_tst
print(df[col].value_counts())
# Out:
# 20     770
# 60     394
# 50     198
# 120    132
# 30     101
# 70      90
# 160     88
# 80      86
# 90      75
# 190     46
# 85      28
# 75      16
# 45      11
# 180     11
# 40       4
# 150      1
# Name: MS SubClass, dtype: int64
# 20     309
# 60     181
# 50      89
# 120     60
# 160     41
# 70      38
# 30      38
# 90      34
# 80      32
# 85      20
# 190     15
# 75       7
# 45       7
# 180      6
# 40       2
# Name: MS SubClass, dtype: int64

# %%
# Show value counts
df = X1_trn
col = 'MS Zoning'
print(df[col].value_counts())

df = X1_tst
print(df[col].value_counts())
# Out:
# RL         1598
# RM          316
# FV          101
# C (all)      19
# RH           14
# A (agr)       2
# I (all)       1
# Name: MS Zoning, dtype: int64
# RL         675
# RM         146
# FV          38
# RH          13
# C (all)      6
# I (all)      1
# Name: MS Zoning, dtype: int64

# %%
# Show value counts
df = X1_trn
col = 'Neighborhood'
print(df[col].value_counts())

df = X1_tst
print(df[col].value_counts())
# Out:
# NAmes      310
# CollgCr    180
# OldTown    163
# Edwards    143
# Somerst    130
# NridgHt    122
# Gilbert    116
# Sawyer     111
# NWAmes      87
# SawyerW     87
# Mitchel     82
# BrkSide     76
# Crawfor     71
# IDOTRR      69
# NoRidge     48
# Timber      48
# StoneBr     38
# SWISU       32
# ClearCr     27
# MeadowV     24
# Blmngtn     22
# BrDale      19
# NPkVill     17
# Veenker     17
# Blueste      6
# Greens       3
# GrnHill      2
# Landmrk      1
# Name: Neighborhood, dtype: int64
# NAmes      133
# CollgCr     87
# OldTown     76
# Somerst     52
# Edwards     51
# Gilbert     49
# NridgHt     44
# NWAmes      44
# Sawyer      40
# SawyerW     38
# Crawfor     32
# Mitchel     32
# BrkSide     32
# IDOTRR      24
# Timber      24
# NoRidge     23
# ClearCr     17
# SWISU       16
# StoneBr     13
# MeadowV     13
# BrDale      11
# Veenker      7
# NPkVill      6
# Blmngtn      6
# Greens       5
# Blueste      4
# Name: Neighborhood, dtype: int64

# %% [markdown]
# # References
#
# * https://towardsdatascience.com/ridge-and-lasso-regression-a-complete-guide-with-python-scikit-learn-e20e34bcbf0b
# * https://stackoverflow.com/questions/41335718/keep-same-dummy-variable-in-training-and-testing-data
